# %%
# !pip install sentencepiece
# !git clone https://github.com/google-research/bert
# Out:
# ...
#      |████████████████████████████████| 1.0MB 2.8MB/s
# ...
# Cloning into 'bert'...
# remote: Enumerating objects: 336, done.
# remote: Total 336 (delta 0), reused 0 (delta 0), pack-reused 336
# Receiving objects: 100% (336/336), 297.11 KiB | 570.00 KiB/s, done.
# Resolving deltas: 100% (183/183), done.

# %%
import os
import sys
import json
import tensorflow as tf

from glob import glob
from google.colab import auth, drive
from tensorflow.keras.utils import Progbar

sys.path.append("bert")
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
auth.authenticate_user()

# %%
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
my_list = ["pakistan", "afghanistan"]

# %%
# !mkdir /content/tmp

# %%
with open('/content/tmp/input.txt', 'w', encoding="utf-8") as f:
    for item in my_list:
        f.write("%s\n" % item)

# %%
BUCKET_NAME = "bert_roman_bucket"
MODEL_DIR = "bert_model" 
PRETRAINING_DIR = "pretraining_data" 
VOC_FNAME = "vocab.txt" 

if BUCKET_NAME:
  BUCKET_PATH = "gs://{}".format(BUCKET_NAME)
else:
  BUCKET_PATH = "."

BERT_GCS_DIR = "{}/{}".format(BUCKET_PATH, MODEL_DIR)
DATA_GCS_DIR = "{}/{}".format(BUCKET_PATH, PRETRAINING_DIR)
INIT_CHECKPOINT = tf.train.latest_checkpoint(BERT_GCS_DIR)

# %%
# !python /content/bert/extract_features.py \
  --input_file='gs://bert_roman_bucket/bert_model/vocab.txt' \
  --output_file='/content/tmp/output.json' \
  --vocab_file='gs://bert_roman_bucket/bert_model/vocab.txt' \
  --bert_config_file='gs://bert_roman_bucket/bert_model/bert_config.json'\
  --init_checkpoint='gs://bert_roman_bucket/bert_model/model.ckpt-1000000' \
  --layers=-1 \
  --max_seq_length=128 \
  --batch_size=8
# Out:
# WARNING:tensorflow:From /content/bert/extract_features.py:419: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/bert/extract_features.py:344: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0301 07:23:34.349342 139701922948992 module_wrapper.py:139] From /content/bert/extract_features.py:344: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /content/bert/extract_features.py:344: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W0301 07:23:34.349541 139701922948992 module_wrapper.py:139] From /content/bert/extract_features.py:344: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
lines = []
for line in open('tmp/output.json', 'r'):
    lines.append(json.loads(line))

# %%
def format_embeddings(lines):
    new_lines = []
    for line in lines:
        temp = {}
        for word in line['features']:
            embedding = word['layers'][0]['values']
            token = word['token']

            temp[token] = embedding

        new_lines.append(temp)
    
    return new_lines

# %%
new_dicts = format_embeddings(lines)

# %%
a = new_dicts[0]['pakistan']
b = new_dicts[1]['afghanistan']
